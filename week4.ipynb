# %% [markdown]
# <a href="https://colab.research.google.com/github/KyunghoonJeon/AI-for-ML/blob/main/week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis/ch_02

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('data/earthquakes.csv')

# %%
df.head()

# %%
df.info()

# %%
df[['mag','magType','type']]

# %%
df['type'].unique()

# %%
df['magType'].unique()

# %%
df1=df.loc[3:10, ['mag', 'magType','type']]

# %%
df1

# %%
df2=df.iloc[3:10, [8,9,21]]

# %%
df2

# %%
df.loc[
    (df.place.str.contains('Arizona')),
    :
]

# %%
df['mag'].sort_values(ascending=False).head(10)

# %%
df.sort_values(by='mag', ascending=False).head(10)

# %%
del df['alert']
df.columns

# %%
df3 = df.pop('mag')
df3

# %%
df4=df.pop('magType')
df4

# %%
pd.concat([df3, df4], axis=1)
